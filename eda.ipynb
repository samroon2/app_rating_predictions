# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import re
import seaborn as sns
from textblob import TextBlob

# %matplotlib inline

# df = pd.read_json('./data/temp_pre/temple__12.json')
df = pd.read_csv('app_ratings.csv')
df.head()
# Out:
#                                         cleaned_text        date  \
# 0                many ads many ads delete app review  2019-03-11
# 1          temple run fun grinning face smiling eyes  2019-03-03
# 2                                    temple run play  2019-02-25
# 3  game bad jump chasing cloths hate pouting face...  2018-11-17
# 4   good game bit doggy grimacing face grinning face  2018-09-25
#
#                                              review  stars  \
# 0  Too many ads. Will delete this app after review.      1
# 1                                        It is fun😄      5
# 2                                              Play      5
# 3                          Cloths I hate is😡😡😡😡😡😡😡😡      1
# 4  It was a good game but it was a bit too doggy 😬😀      4
#
#                                                title     userid  \
# 0                                      Too many ads.  125734925
# 1                                         Temple run  986532366
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450522 entries, 0 to 450521
# Data columns (total 13 columns):
# cleaned_text                449696 non-null object
# date                        450522 non-null object
# review                      450522 non-null object
# stars                       450522 non-null int64
# title                       450512 non-null object
# userid                      450522 non-null int64
# userurl                     450522 non-null object
# version                     450522 non-null object
# review_sentiment            450522 non-null float64
# title_sentiment             450522 non-null float64
# cleaned_review_sentiment    450522 non-null float64
# polsum                      450522 non-null float64
# month_year                  450522 non-null object
# dtypes: float64(4), int64(2), object(7)
# memory usage: 44.7+ MB

# %%
# def sent(text):
#     return TextBlob(text).sentiment[0]

# %%
# df['review_sentiment'] = df.apply(lambda x: sent(x['review']), axis=1)
# df['title_sentiment'] = df.apply(lambda x: sent(x['title']), axis=1)
# df['cleaned_review_sentiment'] = df.apply(lambda x: sent(x['cleaned_text']), axis=1)
# df['stars'] = [int(re.search(r'\d+', x).group()) for x in df['stars']]
# df["polsum"] = df['review_sentiment'] + df['title_sentiment']
# df['month_year'] = df.date.dt.to_period('M')

# %%
af = df.groupby(['month_year', 'stars']).size().to_frame('Counts').reset_index()
af
# Out:
#     month_year  stars  Counts
# 0      2011-08      1       1
# 1      2011-08      2       1
# 2      2011-08      3       1
# 3      2011-08      4       7
# 4      2011-08      5      53
# 5      2011-09      1       7
# 6      2011-09      2       6
# 7      2011-09      3      17
# 8      2011-09      4      88
# 9      2011-09      5     700
# 10     2011-10      1      12
# 11     2011-10      2       9
# 12     2011-10      3      30
# 13     2011-10      4     232
# 14     2011-10      5    1996
# 15     2011-11      1      33
# 16     2011-11      2       8
# 17     2011-11      3      42
# 18     2011-11      4     287
# 19     2011-11      5    2953
# 20     2011-12      1     280
# 21     2011-12      2     147
# 22     2011-12      3     439
# 23     2011-12      4    2412
# 24     2011-12      5   31320
# 25     2012-01      1    1494
# 26     2012-01      2     672
# 27     2012-01      3    1742
# 28     2012-01      4    8707
# 29     2012-01      5  131714
# ...

# %%
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
from bokeh.models import ColumnDataSource, FactorRange
from bokeh.models import ColumnDataSource, HoverTool, Div, BoxZoomTool, ResetTool, WheelZoomTool, PanTool
output_notebook()

subset = af[['month_year', 'stars']]
a = [tuple(x) for x in subset.values]
x = []
for i in a:
    x.append((str(i[0])[:10], str(i[1])))

subs2 = af[['Counts']]
counts = [tuple(x) for x in subs2.values]
source = ColumnDataSource(data=dict(x=x, counts=counts))

t = figure(x_range=FactorRange(*x), plot_height=350, plot_width=900, title="Stars by Month")

t.vbar(x='x', top='counts',width=0.9, source=source)

t.y_range.start = 0
t.x_range.range_padding = 0.1
t.xaxis.major_label_orientation = 1
t.xgrid.grid_line_color = None

show(t)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="f3e537af-1bbb-4994-ae06-7109632f986d" data-root-id="1004"></div>

# %%
# find the quartiles and IQR for each category
groups = df.groupby('stars')
q1 = groups.quantile(q=0.25)
q2 = groups.quantile(q=0.5)
q3 = groups.quantile(q=0.75)
iqr = q3 - q1
upper = q3 + 1.5*iqr
lower = q1 - 1.5*iqr

# find the outliers for each category
def outliers(group):
    cat = group.name
    return group[(group.polsum > upper.loc[cat]['polsum']) | (group.polsum < lower.loc[cat]['polsum'])]['polsum']
out = groups.apply(outliers).dropna()

cats = [1, 2, 3, 4, 5]

# prepare outlier data for plotting, we need coordinates for every outlier.
if not out.empty:
    outx = []
    outy = []
    for cat in cats:
        # only add outliers if they exist
        if not out.loc[cat].empty:
            for value in out[cat]:
                outx.append(cat)

output_notebook()
p = figure(background_fill_color="#EFE8E2", x_range=['1','2','3','4','5', '6'],
           x_axis_label= "Stars", y_axis_label="Sentiment",
        title="Star Ratings Vs Combined Sentiment",
          plot_width=600, plot_height=600)
qmin = groups.quantile(q=0.00)
qmax = groups.quantile(q=1.00)
upper.polsum = [min([x,y]) for (x,y) in zip(list(qmax.loc[:,'polsum']),upper.polsum)]
lower.polsum = [max([x,y]) for (x,y) in zip(list(qmin.loc[:,'polsum']),lower.polsum)]

# stems
p.segment(cats, upper.polsum, cats, q3.polsum, line_color="black")
p.segment(cats, lower.polsum, cats, q1.polsum, line_color="black")

# boxes
p.vbar(cats, 0.7, q2.polsum, q3.polsum, fill_color="#E08E79", line_color="black")
p.vbar(cats, 0.7, q1.polsum, q2.polsum, fill_color="#3B8686", line_color="black")

# whiskers (almost-0 height rects simpler than segments)
p.rect(cats, lower.polsum, 0.2, 0.01, line_color="black")
p.rect(cats, upper.polsum, 0.2, 0.01, line_color="black")

# outliers
if not out.empty:
    p.circle(outx, outy, size=6, color="#F38630", fill_alpha=0.6)

p.xgrid.grid_line_color = None
p.ygrid.grid_line_color = "white"
p.grid.grid_line_width = 2
p.xaxis.major_label_text_font_size="12pt"
p.yaxis.major_label_text_font_size="12pt"

show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1097">Loading BokehJS ...</span>
#     </div>
# ...
#   <div class="bk-root" id="8ebcf876-0567-43c0-b534-245392735ad5" data-root-id="1098"></div>

# %%
groups = df.groupby('stars')
q1 = groups.quantile(q=0.25)
q2 = groups.quantile(q=0.5)
q3 = groups.quantile(q=0.75)
iqr = q3 - q1
upper = q3 + 1.5*iqr
lower = q1 - 1.5*iqr

# find the outliers for each category
def outliers(group):
    cat = group.name
    return group[(group.review_sentiment > upper.loc[cat]['review_sentiment']) | (group.review_sentiment < lower.loc[cat]['review_sentiment'])]['review_sentiment']
out = groups.apply(outliers).dropna()

cats = [1, 2, 3, 4, 5]

# prepare outlier data for plotting, we need coordinates for every outlier.
if not out.empty:
    outx = []
    outy = []
    for cat in cats:
        # only add outliers if they exist
        if not out.loc[cat].empty:
            for value in out[cat]:
                outx.append(cat)

output_notebook()
p = figure(background_fill_color="#EFE8E2", x_range=['1','2','3','4','5', '6'],
           x_axis_label= "Stars", y_axis_label="Sentiment",
        title="Star Ratings Vs Review Sentiment",
          plot_width=600, plot_height=600)
qmin = groups.quantile(q=0.00)
qmax = groups.quantile(q=1.00)
upper.review_sentiment = [min([x,y]) for (x,y) in zip(list(qmax.loc[:,'polsum']),upper.review_sentiment)]
lower.review_sentiment = [max([x,y]) for (x,y) in zip(list(qmin.loc[:,'polsum']),lower.review_sentiment)]

# stems
p.segment(cats, upper.review_sentiment, cats, q3.review_sentiment, line_color="black")
p.segment(cats, lower.review_sentiment, cats, q1.review_sentiment, line_color="black")

# boxes
p.vbar(cats, 0.7, q2.review_sentiment, q3.review_sentiment, fill_color="#E08E79", line_color="black")
p.vbar(cats, 0.7, q1.review_sentiment, q2.review_sentiment, fill_color="#3B8686", line_color="black")

# whiskers (almost-0 height rects simpler than segments)
p.rect(cats, lower.review_sentiment, 0.2, 0.01, line_color="black")
p.rect(cats, upper.review_sentiment, 0.2, 0.01, line_color="black")

# outliers
if not out.empty:
    p.circle(outx, outy, size=6, color="#F38630", fill_alpha=0.6)

p.xgrid.grid_line_color = None
p.ygrid.grid_line_color = "white"
p.grid.grid_line_width = 2
p.xaxis.major_label_text_font_size="12pt"
p.yaxis.major_label_text_font_size="12pt"

show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1314">Loading BokehJS ...</span>
#     </div>
# ...
#   <div class="bk-root" id="0083e062-b5a1-4725-8da2-ebaf2bf83f73" data-root-id="1315"></div>

# %%
df.groupby(['version', 'stars']).mean()
# Out:
#                            userid  review_sentiment  title_sentiment  \
# version       stars
# Version 1.0   5      4.529814e+07          0.221141         0.513542
# Version 1.1   1      2.199578e+07          0.000000         0.000000
#               2      1.620542e+08          0.000000         0.000000
#               3      4.254027e+07          0.333333         0.000000
#               4      1.270208e+08          0.272183         0.152083
#               5      9.209526e+07          0.159171         0.434728
# Version 1.2   1      1.192484e+08         -0.097173        -0.208929
#               2      1.226250e+08         -0.139931         0.216667
#               3      1.327204e+08          0.125092         0.298210
#               4      1.344491e+08          0.192250         0.202130
#               5      1.364903e+08          0.225745         0.278650
# Version 1.3   1      1.556668e+08         -0.118275        -0.183182
# ...

# %%
df.groupby(['version']).agg({'date': {'min_date':np.min, 'max_date':np.max}, 'stars':np.mean, 'review_sentiment':np.mean, 
                             'title_sentiment':np.mean,'polsum':np.mean}).reset_index()
# Out:
# c:\users\c3110\appdata\local\programs\python\python36\lib\site-packages\pandas\core\groupby\groupby.py:4656: FutureWarning: using a dict with renaming is deprecated and will be removed in a future version
#   return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)
#           version        date                 stars review_sentiment  \
#                      min_date    max_date      mean             mean
# 0     Version 1.0  2011-08-04  2011-08-10  5.000000         0.221141
# 1     Version 1.1  2011-08-11  2011-09-13  4.701754         0.172502
# 2     Version 1.2  2011-09-16  2011-10-11  4.809103         0.215829
# 3     Version 1.3  2011-10-11  2011-11-19  4.853087         0.224345
# 4     Version 1.4  2011-11-19  2011-12-03  4.812754         0.204264
# 5   Version 1.4.1  2011-12-03  2016-01-29  4.833568         0.199614
# 6     Version 1.5  2012-08-01  2018-05-29  4.771609         0.214800
# 7     Version 1.6  2012-09-19  2016-03-07  4.716165         0.206523
# ...

# %%
avpol = df.groupby(['month_year']).mean().reset_index()
avpol['month_year'] = pd.to_datetime(avpol['month_year'])

# %%
yfield = 'polsum'
xfield = 'month_year'
hover = HoverTool(tooltips=[(yfield, '@y'), (xfield, '@x{%F}')], formatters={"x": "datetime"})
p = figure(x_axis_label=xfield, y_axis_label=yfield, x_axis_type="datetime", tools=[hover, BoxZoomTool(), 
    ResetTool(), WheelZoomTool(), PanTool()])
p.line(avpol[xfield], avpol[yfield])
output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1586">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="df18578e-afb7-4675-b496-beba0de658bf" data-root-id="1556"></div>

# %%
yfield = 'review_sentiment'
xfield = 'month_year'
hover = HoverTool(tooltips=[(yfield, '@y'), (xfield, '@x{%F}')], formatters={"x": "datetime"})
p = figure(x_axis_label=xfield, y_axis_label=yfield, x_axis_type="datetime", tools=[hover, BoxZoomTool(), 
    ResetTool(), WheelZoomTool(), PanTool()])
p.line(avpol[xfield], avpol[yfield])
p.line(avpol[xfield], avpol['title_sentiment'], color='red')
output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1822">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="d7e652bf-e9bd-4894-b937-5bd5976a0c0e" data-root-id="1787"></div>

# %%
avpol2 = df.groupby(['version']).mean().reset_index()

# %%
hover2 = HoverTool(tooltips=[(yfield, '@y'), (xfield, '@x')])
p = figure(x_axis_label="Stars", y_axis_label="Sentiment", tools=[hover2, BoxZoomTool(), ResetTool(), WheelZoomTool(), PanTool()])
p.circle(avpol2['stars'], avpol2['polsum'])
p.circle(avpol2['stars'], avpol2['review_sentiment'], color='red')
p.circle(avpol2['stars'], avpol2['title_sentiment'], color='green')
show(p)
# Out:
#   <div class="bk-root" id="095eecda-25b5-42f8-bf6e-d9a9cf9bca3d" data-root-id="2740"></div>

# %%
xfield = 'review_sentiment'
yfield = 'title_sentiment'
hover3 = HoverTool(tooltips=[(yfield, '@y'), (xfield, '@x')])
p = figure(x_axis_label=xfield, y_axis_label=yfield, tools=[hover3, BoxZoomTool(), ResetTool(), WheelZoomTool(), PanTool()])
p.circle(avpol2[xfield], avpol2[yfield])
output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2316">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="e8b55f68-c2f3-454b-9f28-5d84b8ac8c50" data-root-id="2286"></div>
